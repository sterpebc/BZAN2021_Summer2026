# %% [markdown]
# # Tech Practice Notebook
#
# This is not a practice test. It's just a notebook that contains a couple of simple problems so you can get a feel for how these Google-hosted Jupyter notebooks work.

# %% [markdown]
# ## Simple Problem 1
#
# Write a function named `discount` that takes two parameters which you may assume are both numbers. The first parameter represents a price, and the second parameter represents a discount percentage. Your function should calculate the discounted price and return it.
#
# For example:
# ```
# discount(100, .20) should return 80.0, the new price if you apply a 20% discount to an item costing $100.
# discount(100, .50) should return 50.0, the new price if you apply a 50% discount to an item costing $100.
# ```

# %%
# Your code for Simple Problem 1 goes in this cell.

# %% [markdown]
# ## Simple Problem 2
#
# Write a function named `repeat` that takes one parameter which you may assume is a string. Your function should return a new string in which every letter of the given string occurs twice in a row.
#
# For example:
# ```
# repeat('abc') should return 'aabbcc'
# repeat('hello') should return 'hheelllloo'
# ```

# %%
# Your code for Simple Problem 2 goes in this cell.

# %% [markdown]
# https://extendsclass.com/sqlite/209d6d2
